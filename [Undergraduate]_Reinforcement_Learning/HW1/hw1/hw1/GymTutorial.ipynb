# %% [markdown]
# # Getting Familiar with Gymnasium

# %% [markdown]
# `Gymnasium` serves as an interface for RL experiments, providing standardized APIs to interact with a variety of environments. `MuJoCo`, on the other hand, provides the physics engine that underpins many of these environments.
#
# * `Gymnasium` is a standardized API for reinforcement learning, offering a broad collection of reference environments. It's designed to be simple and Pythonic, allowing for the representation of general RL problems. Users can create environments, initiate them, execute actions based on a user-defined policy, and manage the environment's state, including resetting it upon termination or truncation of episodes. Here's the documentation you would find useful: [Gymnasium Documentation](https://gymnasium.farama.org).
# * `MuJoCo`, which stands for Multi-Joint dynamics with Contact, is a high-performance physics engine for simulating complex dynamic systems with a focus on robotics, biomechanics, and other areas requiring fast and accurate simulations. It is now open-sourced by DeepMind as of 2022, making it freely available. It includes various environments like `Ant`, `HalfCheetah`, `Hopper`, `Humanoid`, etc. You can see more in the [Gymnasium Documentation on MuJoCo](https://gymnasium.farama.org/environments/mujoco/).
#
# In this tutorial, you'll get to know how to interact with `Gymnasium`'s interface with the `MuJoCo` and some other environments. `Gymnasium` is designed to be universal, making it easy to switch between different environments without changing your setup much.

# %% [markdown]
# ## Installation

# %% [markdown]
# Before we dive into the code, we strongly recommend you check out `installation.md` first and follow the installation procedures. If followed correctly, the requirements listed below would have been already installed.

# %%
# !pip install "gymnasium[mujoco,classic_control]"
# !pip install mediapy
# !pip install torch
# !pip install tensorboard
# !pip install tensorboardX
# !pip install 'moviepy<2.0'
# Out:
# Collecting gymnasium[classic_control,mujoco]
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium[classic_control,mujoco])
#   Downloading numpy-2.4.3-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium[classic_control,mujoco])
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium[classic_control,mujoco])
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium[classic_control,mujoco])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting pygame>=2.1.3 (from gymnasium[classic_control,mujoco])
#   Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[classic_control,mujoco])
#   Downloading mujoco-3.6.0-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting imageio>=2.14.1 (from gymnasium[classic_control,mujoco])
#   Downloading imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: packaging>=23.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from gymnasium[classic_control,mujoco]) (26.0)
# Collecting pillow>=8.3.2 (from imageio>=2.14.1->gymnasium[classic_control,mujoco])
#   Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting absl-py (from mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading etils-1.14.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-win_amd64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Collecting fsspec (from etils[epath]->mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting zipp (from etils[epath]->mujoco>=2.1.5->gymnasium[classic_control,mujoco])
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Downloading mujoco-3.6.0-cp312-cp312-win_amd64.whl (5.8 MB)
#    ---------------------------------------- 0.0/5.8 MB ? eta -:--:--
#    ------- -------------------------------- 1.0/5.8 MB 6.3 MB/s eta 0:00:01
#    ------------------ --------------------- 2.6/5.8 MB 6.3 MB/s eta 0:00:01
#    ------------------------------ --------- 4.5/5.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.8/5.8 MB 7.2 MB/s eta 0:00:00
# Downloading numpy-2.4.3-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.3 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.4/12.3 MB 5.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.3 MB 6.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.3 MB 6.2 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.3 MB 6.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.3 MB 5.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.9/12.3 MB 5.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.2/12.3 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 5.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.3 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 5.1 MB/s eta 0:00:00
# Downloading pygame-2.6.1-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/10.6 MB 6.3 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/10.6 MB 5.3 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/10.6 MB 5.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.7/10.6 MB 5.6 MB/s eta 0:00:02
#    --------------------- ------------------ 5.8/10.6 MB 5.5 MB/s eta 0:00:01
#    ------------------------- -------------- 6.8/10.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 8.1/10.6 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 9.7/10.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 5.7 MB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 952.1/952.1 kB 4.9 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp312-cp312-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.0 MB 5.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.1/7.0 MB 5.1 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/7.0 MB 5.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.2/7.0 MB 5.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 4.4 MB/s eta 0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-win_amd64.whl (559 kB)
#    ---------------------------------------- 0.0/559.5 kB ? eta -:--:--
#    ---------------------------------------- 559.5/559.5 kB 4.8 MB/s eta 0:00:00
# Downloading pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.2 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.3/3.2 MB 3.0 MB/s eta 0:00:01
#    -------------------------- ------------- 2.1/3.2 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 3.6 MB/s eta 0:00:00
# Downloading etils-1.14.0-py3-none-any.whl (172 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: pyopengl, glfw, farama-notifications, zipp, typing-extensions, pygame, pillow, numpy, fsspec, etils, cloudpickle, absl-py, imageio, gymnasium, mujoco
# Successfully installed absl-py-2.4.0 cloudpickle-3.1.2 etils-1.14.0 farama-notifications-0.0.4 fsspec-2026.2.0 glfw-2.10.0 gymnasium-1.2.3 imageio-2.37.3 mujoco-3.6.0 numpy-2.4.3 pillow-12.1.1 pygame-2.6.1 pyopengl-3.1.10 typing-extensions-4.15.0 zipp-3.23.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting mediapy
#   Downloading mediapy-1.2.6-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: ipython in c:\users\minsu\appdata\roaming\python\python312\site-packages (from mediapy) (9.11.0)
# Collecting matplotlib (from mediapy)
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Requirement already satisfied: numpy in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from mediapy) (2.4.3)
# Requirement already satisfied: Pillow in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from mediapy) (12.1.1)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from ipython->mediapy) (5.14.3)
# Collecting contourpy>=1.0.1 (from matplotlib->mediapy)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapy)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapy)
#   Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl.metadata (119 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapy)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from matplotlib->mediapy) (26.0)
# Collecting pyparsing>=3 (from matplotlib->mediapy)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from matplotlib->mediapy) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from jedi>=0.18.2->ipython->mediapy) (0.8.6)
# Requirement already satisfied: wcwidth in c:\users\minsu\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mediapy) (0.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapy) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython->mediapy) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\minsu\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython->mediapy) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\minsu\appdata\roaming\python\python312\site-packages (from stack_data>=0.6.0->ipython->mediapy) (0.2.3)
# Downloading mediapy-1.2.6-py3-none-any.whl (27 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 7.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.1 MB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 7.7 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.9 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------------------------- -------- 1.8/2.3 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 8.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, mediapy
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 mediapy-1.2.6 pyparsing-3.3.2
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting torch
#   Downloading torch-2.10.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from torch) (2026.2.0)
# Collecting setuptools (from torch)
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Downloading torch-2.10.0-cp312-cp312-win_amd64.whl (113.8 MB)
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#    ---------------------------------------- 1.0/113.8 MB 5.6 MB/s eta 0:00:21
#    ---------------------------------------- 1.3/113.8 MB 4.2 MB/s eta 0:00:27
#     --------------------------------------- 2.6/113.8 MB 4.1 MB/s eta 0:00:28
#    - -------------------------------------- 3.9/113.8 MB 4.7 MB/s eta 0:00:24
#    - -------------------------------------- 5.0/113.8 MB 4.6 MB/s eta 0:00:24
#    -- ------------------------------------- 6.0/113.8 MB 4.9 MB/s eta 0:00:23
#    -- ------------------------------------- 7.6/113.8 MB 5.2 MB/s eta 0:00:21
#    -- ------------------------------------- 8.4/113.8 MB 5.0 MB/s eta 0:00:22
#    --- ------------------------------------ 9.7/113.8 MB 5.2 MB/s eta 0:00:21
#    --- ------------------------------------ 11.0/113.8 MB 5.3 MB/s eta 0:00:20
#    ---- ----------------------------------- 12.1/113.8 MB 5.3 MB/s eta 0:00:20
#    ---- ----------------------------------- 13.1/113.8 MB 5.2 MB/s eta 0:00:20
#    ----- ---------------------------------- 14.4/113.8 MB 5.3 MB/s eta 0:00:19
#    ----- ---------------------------------- 16.0/113.8 MB 5.4 MB/s eta 0:00:18
#    ------ --------------------------------- 17.3/113.8 MB 5.5 MB/s eta 0:00:18
#    ------ --------------------------------- 18.6/113.8 MB 5.6 MB/s eta 0:00:18
#    ------- -------------------------------- 20.4/113.8 MB 5.7 MB/s eta 0:00:17
#    ------- -------------------------------- 22.0/113.8 MB 5.8 MB/s eta 0:00:16
#    -------- ------------------------------- 23.3/113.8 MB 5.9 MB/s eta 0:00:16
#    -------- ------------------------------- 24.6/113.8 MB 5.9 MB/s eta 0:00:16
#    --------- ------------------------------ 26.5/113.8 MB 6.0 MB/s eta 0:00:15
#    --------- ------------------------------ 27.5/113.8 MB 6.0 MB/s eta 0:00:15
#    ---------- ----------------------------- 29.1/113.8 MB 6.0 MB/s eta 0:00:15
#    ---------- -----------------------------
# Successfully installed MarkupSafe-3.0.3 filelock-3.25.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 setuptools-82.0.1 sympy-1.14.0 torch-2.10.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (2.4.0)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.78.0-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (2.4.3)
# Requirement already satisfied: packaging in c:\users\minsu\appdata\roaming\python\python312\site-packages (from tensorboard) (26.0)
# Requirement already satisfied: pillow in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (12.1.1)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (6.33.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboard) (82.0.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.1.6-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.5 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 7.8 MB/s eta 0:00:00
# Downloading grpcio-1.78.0-cp312-cp312-win_amd64.whl (4.8 MB)
#    ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#    ---------- ----------------------------- 1.3/4.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.4/4.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.8 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.8/4.8 MB 7.8 MB/s eta 0:00:00
# Downloading markdown-3.10.2-py3-none-any.whl (108 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.6-py3-none-any.whl (225 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, markdown, grpcio, tensorboard
# Successfully installed grpcio-1.78.0 markdown-3.10.2 tensorboard-2.20.0 tensorboard-data-server-0.7.2 werkzeug-3.1.6
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboardX) (2.4.3)
# Requirement already satisfied: packaging in c:\users\minsu\appdata\roaming\python\python312\site-packages (from tensorboardX) (26.0)
# Requirement already satisfied: protobuf>=3.20 in c:\users\minsu\appdata\local\programs\python\python312\lib\site-packages (from tensorboardX) (6.33.5)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.4
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ������ ������ ã�� �� �����ϴ�.

# %%
import os

os.environ["MUJOCO_GL"] = "egl"

# %%
import gymnasium as gym
import mediapy as media
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating a Gymnasium Environment

# %% [markdown]
# Gymnasium (Gym) is our gateway to various reinforcement learning environments, including MuJoCo.
#
# You can easily create a gym environment with `gym.make`. Here's how you can do this with `Ant-v4` environment from `MuJoCo`.
#
# Also, in the following code you may notice the usage of `env.reset` and `env.render`:
# - `env.reset()`: This method resets the environment to its initial state, and returns the observation and additional information of the environment.
# - `env.render()`: This method renders the current state as an image.

# %%
# Initialize the Ant environment
env_name = "Ant-v4"
env = gym.make(env_name, render_mode="rgb_array", terminate_when_unhealthy=False)
print(f"Initialized environment: {env_name}")

initial_obs, info = env.reset()
rendered_state = env.render()
plt.imshow(rendered_state)

# %% [markdown]
#  The `Ant-v4` environment simulates a quadruped robot in a 2D space. The ant is a 3D robot consisting of one torso (free rotational body) with four legs attached to it with each leg having two links. The goal is to coordinate the four legs to move in the forward (right) direction by applying torques on the eight hinges connecting the two links of each leg and the torso (nine parts and eight hinges).

# %% [markdown]
# The environment defines an attribute called the `observation_space` and `action_space`.
# You can see how it looks like below.
# The observation space of `Ant-v4` has 27 distinct elements, and the action space has 8 dimensions.
# If you want to figure out what each dimension of the observations and the actions means, it would be helpful to see the documents of the environment.
# [Ant Documentation](https://www.gymlibrary.dev/environments/mujoco/ant/)

# %%
obs_space = env.observation_space
action_space = env.action_space
print(f"The observation space: {obs_space}")
print(f"The action space: {action_space}")

# %% [markdown]
# As we previously discussed, we can create many other environments with `gym.make`, with the general interface provided with `gym`.
#
# Here's some other examples, which is not actually from `MuJoCo`, but great for illustrating different observation and action spaces are possible:

# %%
def create_and_visualize_gym_env(env_name):
    env = gym.make(env_name, render_mode="rgb_array")
    env.reset()
    rendered_image = env.render()
    plt.title(env_name)
    plt.imshow(rendered_image)
    plt.show()

    print(f"The observation space of {env_name}: {env.observation_space}")
    print(f"The action space of {env_name}: {env.action_space}")
    return env


create_and_visualize_gym_env("CartPole-v1")

# %% [markdown]
# `CartPole-v1` has discrete action space, where the agent can choose to push the cart to the left or to the right.
# The goal of the agent is to keep the pole balanced on the cart for as long as possible.

# %%
create_and_visualize_gym_env("FrozenLake-v1")

# %% [markdown]
# `FrozenLake-v1` environment has a 4x4 grid as an observation space, where each value represents different tiles in the grid.
# In this environment, the agent controls the movement of a character in a grid world. Some tiles of the grid are walkable, and others lead to the agent falling into the water. Additionally, the movement direction of the agent is uncertain and only partially depends on the chosen direction. The agent is rewarded for finding a walkable path to a goal tile.
#
# You can see that `FrozenLake-v1` has discrete observation space as well as discrete action space.

# %% [markdown]
# ## Interacting with the Environment

# %% [markdown]
# To interact with the environment, you can use the methods of the `Env` class. Here's the two important functions.
# - `reset`: This function resets the environment to its initial state, and returns the observation of the environment corresponding to the initial state.
# - `step` : This function takes an action as an input and applies it to the environment, which leads to the environment transitioning to a new state. The reset function returns five things:
#
# 1. `observation`: The observation of the state of the environment.
# 2. `reward`: The reward that you can get from the environment after executing the action that was given as the input to the step function.
# 3. `terminated`: A boolean indicating whether the episode has ended due to reaching a terminal state.
# 4. `truncated`: A boolean indicating whether the episode was cut off due to an artificial time limit or other constraints.
# 5. `info`: This provides additional information depending on the environment, such as number of lives left, or general information that may be conducive in debugging.

# %% [markdown]
# Let's test with a simple code that takes a single step of the environment with a random action. Note here that you can sample a random action from the action space using `env.action_space.sample()`.

# %%
# Create the environment
env = gym.make("Ant-v4", render_mode="rgb_array", terminate_when_unhealthy=False)

# Reset the environment and print the initial observation
obs, info = env.reset()
print("The initial observation is {}".format(obs))

# Sample a random action from the entire action space
random_action = env.action_space.sample()

# Take the action and get the new observation space
new_obs, reward, terminated, truncated, info = env.step(random_action)
print("The new observation is {}".format(new_obs))
print("The reward is {}".format(reward))
print("Is the environment terminated?: {}".format(terminated))
print("Is the environment truncated?: {}".format(truncated))
print("Additional informations: {}".format(info))

# %%
rendered_image = env.render()
plt.imshow(rendered_image)

# %% [markdown]
# Now that you figured out how to take an environment step, let's collect and visualize trajectories from the environment with random policy.
#
# In reinforcement learning, an `episode` represents a sequence of steps taken by an agent from the initial state to a terminal state.
# We will now simulate the environment's behavior under a random policy, capturing each step as a frame. The run_episode function executes `frames_per_episodes` steps and return the observations (states).

# %%
# Define parameters for our simulation
frames_per_episode = 300  # Number of steps (frames) per episode

# %%
# Function to simulate an episode with a random policy
def run_episode(env, frames_per_episode):
    frames = []  # Collect frames for video rendering
    env.reset()
    for _ in range(frames_per_episode):
        frames.append(env.render())
        action = env.action_space.sample()  # Random action
        new_obs, reward, truncated, terminated, info = env.step(action)
        if truncated or terminated:
            break
    return frames


# Visualize one episode with a random policy
frames = run_episode(env, frames_per_episode)

media.show_video(frames, fps=30)

# %% [markdown]
# You can also reset the environment using `env.reset()`. Note that the return value of the reset function is the initial state.

# %%
ob = env.reset()
print("initial observation: {}\n".format(ob))
rendered_image = env.render()
media.show_image(rendered_image)

# %% [markdown]
# Now let's visualize random trajectories with other environments that we discussed before.

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
ob, info = env.reset()

# Visualize 10 episodes with a random policy
whole_frames = []
for _ in range(10):
    frames = run_episode(env, frames_per_episode=100)
    whole_frames.extend(frames)

media.show_video(whole_frames, fps=30)

# %%
env = gym.make("FrozenLake-v1", render_mode="rgb_array")
ob, info = env.reset()

# Visualize 10 episodes with a random policy
whole_frames = []
for _ in range(10):
    frames = run_episode(env, frames_per_episode=100)
    whole_frames.extend(frames)

media.show_video(whole_frames, fps=10)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Now you learned how to create and visualize a gym environment, and how to simulate an episode with a random policy! Feel free to try some other environments that you can find from [gymnasium documentation](https://gymnasium.farama.org/).
